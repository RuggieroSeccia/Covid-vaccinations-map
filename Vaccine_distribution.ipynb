# %% [markdown]
# # Analysing covid vaccine distribution

# %%
import plotly.express as px
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv')
df.sort_values(by=['date','location'],inplace=True)
df.head()
# Out:
#               location iso_code        date  total_vaccinations  \
# 1776           England      NaN  2020-12-13             55576.0
# 4145  Northern Ireland      NaN  2020-12-13              3623.0
# 5036          Scotland      NaN  2020-12-13             19009.0
# 5944    United Kingdom      GBR  2020-12-13             86465.0
# 6149             Wales      NaN  2020-12-13              8257.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1776            55576.0                      NaN                     NaN
# 4145             3623.0                      NaN                     NaN
# 5036            19009.0                      NaN                     NaN
# 5944            86465.0                      NaN                     NaN
# 6149             8257.0                      NaN                     NaN
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 1776                 NaN                            0.10
# 4145                 NaN                            0.19
# 5036                 NaN                            0.35
# 5944                 NaN                            0.13
# 6149                 NaN                            0.26
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 1776                           0.10                                  NaN
# 4145                           0.19                                  NaN
# 5036                           0.35                                  NaN
# 5944                           0.13                                  NaN
# 6149                           0.26                                  NaN
#
#       daily_vaccinations_per_million
# 1776                             NaN
# 4145                             NaN
# 5036                             NaN
# 5944                             NaN
# 6149                             NaN

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### All the countries should consider the same dates

# %%
date_max = df.date.max()
date_min = df.date.min()

# create dummy dataframes 
df_dates = pd.DataFrame(data=pd.date_range(date_min,date_max),columns=['date'])
df_states = pd.DataFrame(data=df.location.unique(),columns=['location'])

df_dates['_tmpkey'] = 1
df_states['_tmpkey'] = 1

# make the cartesian product
df_dates_states = pd.merge(df_dates, df_states, on='_tmpkey').drop('_tmpkey', axis=1)
df_dates_states.sort_values(by=['date','location'],inplace=True)

# transform the date 
df['date'] = pd.to_datetime(df['date'],format='%Y-%m-%d')

# join the df to add missing dates
df = pd.merge(df, df_dates_states, on= ['date','location'],how='outer')
df.head()
# Out:
#            location iso_code       date  total_vaccinations  \
# 0           England      NaN 2020-12-13             55576.0
# 1  Northern Ireland      NaN 2020-12-13              3623.0
# 2          Scotland      NaN 2020-12-13             19009.0
# 3    United Kingdom      GBR 2020-12-13             86465.0
# 4             Wales      NaN 2020-12-13              8257.0
#
#    people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0            55576.0                      NaN                     NaN
# 1             3623.0                      NaN                     NaN
# 2            19009.0                      NaN                     NaN
# 3            86465.0                      NaN                     NaN
# 4             8257.0                      NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                            0.10
# 1                 NaN                            0.19
# 2                 NaN                            0.35
# 3                 NaN                            0.13
# 4                 NaN                            0.26
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                           0.10                                  NaN
# 1                           0.19                                  NaN
# 2                           0.35                                  NaN
# 3                           0.13                                  NaN
# 4                           0.26                                  NaN
#
#    daily_vaccinations_per_million
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %% [markdown]
# ### Change dates format

# %%
# save a copy as string
df['date_str'] = df['date'].apply(str)

# %%
df.sort_values(by=['date','location'],inplace=True)

# %% [markdown]
# ### Fix cumulated columns

# %%
df.isnull().sum()
# Out:
# location                                  0
# iso_code                               6291
# date                                      0
# total_vaccinations                     8138
# people_vaccinated                      8575
# people_fully_vaccinated                9742
# daily_vaccinations_raw                 8754
# daily_vaccinations                     6124
# total_vaccinations_per_hundred         8138
# people_vaccinated_per_hundred          8575
# people_fully_vaccinated_per_hundred    9742
# daily_vaccinations_per_million         6124
# date_str                                  0
# dtype: int64

# %%
# fill missing values
col_ffill = [
    'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated',
    'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
    'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million'
]

for c in col_ffill:
    df[c] = df.groupby('location')[c].fillna(method='ffill')
    
# fill the iso_code
df['iso_code'] =df.groupby(by='location')['iso_code'].fillna(method='ffill')
df['iso_code'] =df.groupby(by='location')['iso_code'].fillna(method='bfill')

# %% [markdown]
# ### Include population information

# %%
# include most recent population information
pop = pd.read_csv('https://raw.githubusercontent.com/datasets/population/master/data/population.csv')
pop= pop[pop['Year']==pop['Year'].max()]
pop.head()
# Out:
#                        Country Name Country Code  Year       Value
# 58                       Arab World          ARB  2018   419790588
# 117          Caribbean small states          CSS  2018     7358965
# 176  Central Europe and the Baltics          CEB  2018   102511922
# 235      Early-demographic dividend          EAR  2018  3249140605
# 294             East Asia & Pacific          EAS  2018  2328220870

# %%
df = pd.merge(df,pop,left_on = 'iso_code',right_on = 'Country Code',how='left')
df.drop(['Country Name', 'Country Code', 'Year'],axis=1,inplace=True)
df.head()
# Out:
#    location iso_code       date  total_vaccinations  people_vaccinated  \
# 0   Albania      ALB 2020-12-13                 NaN                NaN
# 1   Algeria      DZA 2020-12-13                 NaN                NaN
# 2   Andorra      AND 2020-12-13                 NaN                NaN
# 3    Angola      AGO 2020-12-13                 NaN                NaN
# 4  Anguilla      AIA 2020-12-13                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                 NaN
# 2                      NaN                     NaN                 NaN
# 3                      NaN                     NaN                 NaN
# 4                      NaN                     NaN                 NaN
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
#
#               date_str       Value
# 0  2020-12-13 00:00:00   2866376.0
# 1  2020-12-13 00:00:00  42228429.0
# 2  2020-12-13 00:00:00     77006.0
# 3  2020-12-13 00:00:00  30809762.0
# 4  2020-12-13 00:00:00         NaN

# %%
col = ['total_vaccinations','people_vaccinated','people_fully_vaccinated']
for c in col:
    df[c+'_pop']=df[c]/df['Value']

# %%
df.rename(columns={'people_vaccinated_pop':'% vaccinated (>=1 dose)',
                  'people_fully_vaccinated_pop': '% fully vaccinated',
                  'total_vaccinations_pop': 'Total doses distributed'},inplace=True)

# %%
feat = '% vaccinated (>=1 dose)'
fig = px.choropleth(df, locations="iso_code",
                    color=feat, 
                    hover_name="location",
                    hover_data = ['Total doses distributed','% fully vaccinated'],
                    color_continuous_scale=px.colors.sequential.Plasma,
                    range_color=[df[feat].min(),df[feat].max()*0.5],
                   animation_frame='date_str',
                   animation_group='location'
                   )

fig.update_layout(margin={'t':50,
                         'b':0,
                         'r':3,
                         'l':3});

# %%
fig.show()
# Out:
# <div>                            <div id="fa9bd3ee-21c2-4ce0-9752-88b303696cfd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa9bd3ee-21c2-4ce0-9752-88b303696cfd")) {                    Plotly.newPlot(                        "fa9bd3ee-21c2-4ce0-9752-88b303696cfd",                        [{"coloraxis": "coloraxis", "customdata": [[null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [0.0013010013911453724, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null]], "geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>date_str=2020-12-13 00:00:00<br>iso_code=%{location}<br>Total doses distributed=%{customdata[0]}<br>% fully vaccinated=%{customdata[1]}<br>% vaccinated (>=1 dose)=%{z}<extra></extra>", "hovertext": ["Albania", "Algeria", "Andorra", "Angola", "Anguilla", "Argentina", "Australia", "Austria", "Azerbaijan", "Bahrain", "Bangladesh", "Barbados", "Belarus", "Belgium", "Belize", "Bermuda", "Bolivia", "Brazil", "Bulgaria", "Cambodia", "Canada", "Cayman Islands", "Chile", "China", "Colombia", "Costa Rica", "Cote d'Ivoire", "Croatia", "Cyprus", "Czechia", "Denmark", "Dominica", "Dominican Republic", "Ecuador", "Egypt", "El Salvador", "England", "Estonia", "European Union", "Faeroe Islands", "Falkland Islands", "Finland", "France", "Germany", "Ghana", "Gibraltar", "Greece", "Greenland", "Grenada", "Guatemala", "Guernsey", "Guyana", "Honduras", "Hong Kong", "Hungary", "Iceland", "India", "Indonesia", "Iran", "Ireland", "Isle of Man", "Israel", "Italy", "Japan", "Jersey", "Jordan", "Kazakhstan", "Kenya", "Kuwait", "Latvia", "Lebanon", "Liechtenstein", "Lithuania", "Luxembourg", "Macao", "Malaysia", "Maldives", "Malta", "Mauritius", "Mexico", "Moldova", "Monaco", "Mongolia", "Montenegro", "Montserrat", "Morocco", "Myanmar", "Nepal", "Netherlands", "New Zealand", "Northern Cyprus", "Northern Ireland", "Norway", "Oman", "Pakistan", "Panama", "Paraguay", "Peru", "Philippines", "Poland", "Portugal", "Qatar", "Romania", "Russia", "Rwanda", "Saint Helena",  ...
