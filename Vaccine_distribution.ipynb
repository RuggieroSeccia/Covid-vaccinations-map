# %% [markdown]
# # Analysing covid vaccine distribution

# %%
import plotly.express as px
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv')
df.sort_values(by=['date','location'],inplace=True)
df.head()
# Out:
#               location iso_code        date  total_vaccinations  \
# 1828           England      NaN  2020-12-13             55576.0
# 4235  Northern Ireland      NaN  2020-12-13              3623.0
# 5141          Scotland      NaN  2020-12-13             19009.0
# 6072    United Kingdom      GBR  2020-12-13             86465.0
# 6287             Wales      NaN  2020-12-13              8257.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1828            55576.0                      NaN                     NaN
# 4235             3623.0                      NaN                     NaN
# 5141            19009.0                      NaN                     NaN
# 6072            86465.0                      NaN                     NaN
# 6287             8257.0                      NaN                     NaN
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 1828                 NaN                            0.10
# 4235                 NaN                            0.19
# 5141                 NaN                            0.35
# 6072                 NaN                            0.13
# 6287                 NaN                            0.26
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 1828                           0.10                                  NaN
# 4235                           0.19                                  NaN
# 5141                           0.35                                  NaN
# 6072                           0.13                                  NaN
# 6287                           0.26                                  NaN
#
#       daily_vaccinations_per_million
# 1828                             NaN
# 4235                             NaN
# 5141                             NaN
# 6072                             NaN
# 6287                             NaN

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### All the countries should consider the same dates

# %%
date_max = df.date.max()
date_min = df.date.min()

# create dummy dataframes 
df_dates = pd.DataFrame(data=pd.date_range(date_min,date_max),columns=['date'])
df_states = pd.DataFrame(data=df.location.unique(),columns=['location'])

df_dates['_tmpkey'] = 1
df_states['_tmpkey'] = 1

# make the cartesian product
df_dates_states = pd.merge(df_dates, df_states, on='_tmpkey').drop('_tmpkey', axis=1)
df_dates_states.sort_values(by=['date','location'],inplace=True)

# transform the date 
df['date'] = pd.to_datetime(df['date'],format='%Y-%m-%d')

# join the df to add missing dates
df = pd.merge(df, df_dates_states, on= ['date','location'],how='outer')
df.head()
# Out:
#            location iso_code       date  total_vaccinations  \
# 0           England      NaN 2020-12-13             55576.0
# 1  Northern Ireland      NaN 2020-12-13              3623.0
# 2          Scotland      NaN 2020-12-13             19009.0
# 3    United Kingdom      GBR 2020-12-13             86465.0
# 4             Wales      NaN 2020-12-13              8257.0
#
#    people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0            55576.0                      NaN                     NaN
# 1             3623.0                      NaN                     NaN
# 2            19009.0                      NaN                     NaN
# 3            86465.0                      NaN                     NaN
# 4             8257.0                      NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# 0                 NaN                            0.10
# 1                 NaN                            0.19
# 2                 NaN                            0.35
# 3                 NaN                            0.13
# 4                 NaN                            0.26
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                           0.10                                  NaN
# 1                           0.19                                  NaN
# 2                           0.35                                  NaN
# 3                           0.13                                  NaN
# 4                           0.26                                  NaN
#
#    daily_vaccinations_per_million
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %% [markdown]
# ### Change dates format

# %%
# save a copy as string
df['date_str'] = df['date'].apply(str)

# %%
df.sort_values(by=['date','location'],inplace=True)

# %% [markdown]
# ### Fix cumulated columns

# %%
# fill missing values
col_ffill = [
    'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated',
    'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
    'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million'
]

for c in col_ffill:
    df[c] = df.groupby('location')[c].fillna(method='ffill')
    
# fill the iso_code
df['iso_code'] =df.groupby(by='location')['iso_code'].fillna(method='ffill')
df['iso_code'] =df.groupby(by='location')['iso_code'].fillna(method='bfill')

# %% [markdown]
# ### Include population information

# %%
# include most recent population information
pop = pd.read_csv('https://raw.githubusercontent.com/datasets/population/master/data/population.csv')
pop= pop[pop['Year']==pop['Year'].max()]
pop.head()
# Out:
#                        Country Name Country Code  Year       Value
# 58                       Arab World          ARB  2018   419790588
# 117          Caribbean small states          CSS  2018     7358965
# 176  Central Europe and the Baltics          CEB  2018   102511922
# 235      Early-demographic dividend          EAR  2018  3249140605
# 294             East Asia & Pacific          EAS  2018  2328220870

# %%
df = pd.merge(df,pop,left_on = 'iso_code',right_on = 'Country Code',how='left')
df.drop(['Country Name', 'Country Code', 'Year'],axis=1,inplace=True)
df.head()
# Out:
#    location iso_code       date  total_vaccinations  people_vaccinated  \
# 0   Albania      ALB 2020-12-13                 NaN                NaN
# 1   Algeria      DZA 2020-12-13                 NaN                NaN
# 2   Andorra      AND 2020-12-13                 NaN                NaN
# 3    Angola      AGO 2020-12-13                 NaN                NaN
# 4  Anguilla      AIA 2020-12-13                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                 NaN
# 2                      NaN                     NaN                 NaN
# 3                      NaN                     NaN                 NaN
# 4                      NaN                     NaN                 NaN
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
#
#               date_str       Value
# 0  2020-12-13 00:00:00   2866376.0
# 1  2020-12-13 00:00:00  42228429.0
# 2  2020-12-13 00:00:00     77006.0
# 3  2020-12-13 00:00:00  30809762.0
# 4  2020-12-13 00:00:00         NaN

# %%
col = ['total_vaccinations','people_vaccinated','people_fully_vaccinated']
for c in col:
    df[c+'_pop']=df[c]/df['Value']

# %%
df.rename(columns={'people_vaccinated_pop':'% vaccinated (>=1 dose)',
                  'people_fully_vaccinated_pop': '% fully vaccinated',
                  'total_vaccinations_pop': 'Total doses distributed/population'},inplace=True)

# %%
feat = 'Total doses distributed/population'
fig = px.choropleth(df, locations="iso_code",
                    color=feat, 
                    hover_name="location",
                    hover_data = [feat,'% fully vaccinated'],
                    color_continuous_scale=px.colors.sequential.Plasma,
                    range_color=[df[feat].min(),df[feat].max()*0.3],
                   animation_frame='date_str',
                   animation_group='location'
                   )

fig.update_layout(margin={'t':50,
                         'b':0,
                         'r':3,
                         'l':3});

# %%
fig.show()
# Out:
# <div>
#
#
#             <div id="da63cc88-1e38-418b-bb6e-b73128550482" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("da63cc88-1e38-418b-bb6e-b73128550482")) {
#                     Plotly.newPlot(
#                         'da63cc88-1e38-418b-bb6e-b73128550482',
#                         [{"coloraxis": "coloraxis", "customdata": [[null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [0.0013010013911453724, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null], [null, null]], "geo": "geo", "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>date_str=2020-12-13 00:00:00<br>Total doses distributed/population=%{z}<br>% fully vaccinated=%{customdata[1]}<br>iso_code=%{location}", "hovertext": ["Albania", "Algeria", "Andorra", "Angola", "Anguilla", "Argentina", "Australia", "Austria", "Azerbaijan", "Bahrain", "Bangladesh", "Barbados", "Belarus", "Belgium", "Belize", "Bermuda", "Bolivia", "Brazil", "Bulgaria", "Cambodia", "Canada", "Cayman Islands", "Chile", "China", "Colombia", "Costa Rica", "Cote d'Ivoire", "Croatia", "Cyprus", "Czechia", "Denmark", "Dominica", "Dominican Republic", "Ecuador", "Egypt", "El Salvador", "England", "Estonia", "European Union", "Faeroe Islands", "Falkland Islands", "Finland", "France", "Germany", "Ghana", "Gibraltar", "Greece", "Greenland", "Grenada", "Guatemala", "Guernsey", "Guyana", "Honduras", "Hong Kong", "Hungary", "Iceland", "India", "Indonesia", "Iran", "Ireland", "Isle of Man", "Israel", "Italy", "Japan", "Jersey", "Jordan", "Kazakhstan", "Kenya", "Kuwait", "Latvia", "Lebanon", "Liechtenstein", "Lithuania", "Luxembourg", "Macao", "Malaysia", "Maldives", "Malta", "Mauritius", "Mexico", "Moldova", "Monaco", "Mongolia", "Montenegro", "Montserrat", "Morocco", "Myanmar", "Nepal", "Netherlands", "New Zealand", "Northern Cyprus", "Northern Ireland", "Norway", "Oman", "Pakistan", "Panama", "Paraguay", "Peru", "Philippines", "Poland", "Portugal", "Qatar", "Romania", "Russia", "Rwanda", "Saint Helena", "Saint Lucia", "San Marino", "Saudi Arabia", "Scotland", "Senegal", "Serbia", "Seychelles", "Singapore", "Slovakia", "Slovenia", "South Africa", "South Korea", "Spain", "Sri Lanka", "Sweden", "Switzerland", "Thailand", "Trinidad and Tobago", "Tunisia", "Turkey", "Turks and Caicos Islands", "Uganda", "Ukraine", "United Arab Emirates", "United Kingdom", "United States", "Uruguay", "Venezuela", "Vietnam", "Wales", "World", "Zimbabwe"], "ids": ["Albania", "Algeria", "Andorra", " ...
